# %% [markdown]
# <a href="https://colab.research.google.com/github/aparnah30/ACL_Training/blob/main/Untitled32.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.5/921.5 kB 31.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

results = model.train(data="/content/dataset_colab.yaml", epochs=20)

results = model.val()
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !pip install onnx
# !pip install onnxruntime-gpu onnxslim
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 90.6 MB/s eta 0:00:00
# ...

# %%
import onnx
success = model.export(format="onnx")
# Out:
# Ultralytics 8.3.78 🚀 Python-3.11.11 torch-2.5.1+cu121 CPU (Intel Xeon 2.00GHz)
#
# PyTorch: starting from 'runs/detect/train3/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 14, 8400) (6.0 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.48...
# ONNX: export success ✅ 1.0s, saved as 'runs/detect/train3/weights/best.onnx' (11.7 MB)
#
# Export complete (1.4s)
# Results saved to /content/runs/detect/train3/weights
# Predict:         yolo predict task=detect model=runs/detect/train3/weights/best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs/detect/train3/weights/best.onnx imgsz=640 data=/content/dataset_colab.yaml
# Visualize:       https://netron.app

# %%
from google.colab import files
files.download("/content/runs/detect/train3/weights/best.onnx")

# %%
from google.colab import files
files.download("/content/runs/detect/train3/weights/best.pt")

# %%
import cv2
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/best.pt")

image_path = "/content/samp.jpeg"
results = model.predict(image_path)

image = cv2.imread(image_path)

for result in results:
    for box in result.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        confidence = box.conf[0].item()
        class_id = int(box.cls[0].item())
        label = f"Class {class_id}: {confidence:.2f}"

        print(f"Detected Class {class_id} - Coordinates: ({x1}, {y1}), ({x2}, {y2})")

        cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)
        cv2.putText(image, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

print(f"Total objects detected: {len(results[0].boxes)}")

# cv2.imshow("Predictions", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# image 1/1 /content/samp.jpeg: 416x640 1 gloves, 4 helmets, 2 shoess, 4 vests, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 640)
# Detected Class 9 - Coordinates: (72, 71), (88, 95)
# Detected Class 9 - Coordinates: (23, 67), (39, 95)
# Detected Class 9 - Coordinates: (202, 35), (231, 92)
# Detected Class 1 - Coordinates: (28, 51), (42, 61)
# Detected Class 1 - Coordinates: (152, 26), (179, 49)
# Detected Class 1 - Coordinates: (192, 11), (218, 29)
# Detected Class 1 - Coordinates: (76, 59), (86, 66)
# Detected Class 8 - Coordinates: (39, 126), (50, 132)
# Detected Class 8 - Coordinates: (30, 126), (38, 133)
# Detected Class 0 - Coordinates: (246, 72), (259, 84)
# Detected Class 9 - Coordinates: (96, 84), (116, 109)
# Total objects detected: 11
